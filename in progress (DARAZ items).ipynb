# %%
import requests
from bs4 import BeautifulSoup as soup
from time import sleep
from selenium import webdriver

#url of the website we want to scrape which in this case is the url of daraz.pk for swimsuits
my_url = "https://www.daraz.pk/catalog/?q=cup&_keyori=ss&from=input&spm=a2a0e.pdp.search.go.1bceWUVcWUVcgC"
driver = webdriver.Chrome(executable_path='C:\\Users\\Elitebook 850 G3\\anaconda\\New folder\\Lib\\site-packages\\jedi\\third_party\\typeshed\\stdlib\\3\\os\\chromedriver.exe')

#driver = webdriver.Chrome()
driver.get(my_url)
print(driver)
sleep(4)

page = driver.page_source
driver.close()
print(page)
pagesrc = soup(page, 'html.parser')

#making a container to save all the data in
container = pagesrc.find('div', {'class':'c1_t2i'})

#our gallery is the product-item
gallery = container.find_all('div', {'class':'c2prKC'})

sleep(1)
# Out:
# <selenium.webdriver.chrome.webdriver.WebDriver (session="696c16bfd1bd68308c3914104cb39cfd")>
# <html lang="en"><head>
#     <meta charset="utf-8">
#     <meta name="data-spm" content="a2a0e">
#     <meta name="google" content="notranslate">
#
#         <meta http-equiv="x-ua-compatible" content="ie=edge">
#         <meta name="viewport" content="width=device-width">
#
#
#
#     <link rel="stylesheet" href="//laz-g-cdn.alicdn.com/lzdmod/im/5.0.86/index.css"><link rel="dns-prefetch" href="//laz-g-cdn.alicdn.com">
#     <link rel="dns-prefetch" href="//laz-img-cdn.alicdn.com">
#
#     <title>cup - Buy cup at Best Price in Pakistan | www.daraz.pk</title>
#     <meta name="description" content="cup Pakistan - Shop for best cup online at www.daraz.pk">
#     <meta name="google-site-verification" content="25ZiIC89hBvAEL0Sgu7Ffw07GXU_d4CXtFvWyK3wMjo">
#
#     <meta name="robots" content="index, follow">
#
#
#
#
# ...

# %%
container
# Out:
# <div class="c1_t2i" data-qa-locator="general-products" data-spm="list"><div class="c2prKC" data-aplus-ae="x1_7a433702" data-item-id="224836474" data-qa-locator="product-item" data-sku-simple="" data-spm-anchor-id="a2a0e.searchlist.list.i0.57b22b8ecjWIwx" data-tracking="product-card"><div class="c3e8SH"><div class="c5TXIP"><div class="c2iYAv"><div class="cRjKsc"><a age="0" href="//www.daraz.pk/products/multicolorfull-heat-resistant-glass-mugs-with-lid-and-straw-500ml-round-i224836474-s1443318137.html?search=1"><img age="0" alt="Multicolorfull Heat Resistant Glass Mugs with Lid and Straw - 500ML (Round)" class="c1ZEkM" src="https://static-01.daraz.pk/p/e626ce1ebaf10c1c9d1dd807e831ad89.jpg"/></a></div></div><div class="c3KeDq"><div class="c3vCyH"><i class="ic-dynamic-badge ic-dynamic-badge-lazMall ic-dynamic-group-1" style='background-image: url("//laz-img-cdn.alicdn.com/tfs/TB1rYuurhTpK1RjSZFMXXbG_VXa-205-48.png"); width: 68.3333px; height: 16px;'></i></div><div class="c16H9d"><a age="
# ...

# %%
gallery =container.find_all('div', {'class':'cRjKsc'})
anchor=[]
for i in gallery:
    anchor.append(i.find("a"))
links=[]
for i in anchor:
    links.append("https:"+i.get("href"))

# %%
links
# Out:
# ['https://www.daraz.pk/products/multicolorfull-heat-resistant-glass-mugs-with-lid-and-straw-500ml-round-i224836474-s1443318137.html?search=1',
#  'https://www.daraz.pk/products/pyrex-2-cup-500ml-glass-measuring-cup-i2527700-s10840378.html?search=1',
#  'https://www.daraz.pk/products/white-mug-customized-picture-with-your-design-by-genie-mall-i221335549-s1435821794.html?search=1',
#  'https://www.daraz.pk/products/magic-mug-customized-picture-with-your-design-printing-i209182900-s1415276490.html?search=1',
#  'https://www.daraz.pk/products/2-pcs-portable-cartoon-printed-plastic-foldable-magic-cup-glass-for-kids-water-drinker-glass-for-school-children-i248555662-s1466303328.html?search=1',
#  'https://www.daraz.pk/products/metal-straw-premium-stainless-steel-metal-drinking-straw-straws-reusable-i216919633-s1426971224.html?search=1',
#  'https://www.daraz.pk/products/pack-of-2-glass-mason-jars-with-handle-and-straw-for-random-colors-i143614975-s1304760896.html?search=1',
# ...

# %%
#driver.get("https://www.daraz.pk/products/pyrex-2-cup-500ml-glass-measuring-cup-i2527700-s10840378.html?search=1')

# %%
my_url = "https://www.daraz.pk/products/pyrex-2-cup-500ml-glass-measuring-cup-i2527700-s10840378.html?search=1"
driver = webdriver.Chrome(executable_path='C:\\Users\\Elitebook 850 G3\\anaconda\\New folder\\Lib\\site-packages\\jedi\\third_party\\typeshed\\stdlib\\3\\os\\chromedriver.exe')


#driver = webdriver.Chrome()
driver.get(my_url)
print(driver)
sleep(4)

page = driver.page_source
driver.close()

pagesrc = soup(page, 'html.parser')

#making a container to save all the data in
container = pagesrc.find('div', {'class':'container-star pdp-review-summary__stars pdp-stars_size_s'})
data= pagesrc.find('div', {'class':'pdp-block pdp-block__product-detail'})
delivery= pagesrc.find('div', {'class':'delivery'})

responses=pagesrc.find('div', {'class':'seller-container'})
content=pagesrc.find('div', {'class':'content'})

#our gallery is the product-item
gallery = container.find_all('div', {'class':'pdp-mod-product-badge-wrapper'})

sleep(1)
#container-star pdp-review-summary__stars pdp-stars_size_s
container
# Out:
# <selenium.webdriver.chrome.webdriver.WebDriver (session="892e132fa2521ccc65885f089a3b89dc")>
# <div class="container-star pdp-review-summary__stars pdp-stars_size_s"><img class="star" src="//laz-img-cdn.alicdn.com/tfs/TB14SXtAXOWBuNjy0FiXXXFxVXa-30-30.png"/><img class="star" src="//laz-img-cdn.alicdn.com/tfs/TB14SXtAXOWBuNjy0FiXXXFxVXa-30-30.png"/><img class="star" src="//laz-img-cdn.alicdn.com/tfs/TB14SXtAXOWBuNjy0FiXXXFxVXa-30-30.png"/><img class="star" src="//laz-img-cdn.alicdn.com/tfs/TB14SXtAXOWBuNjy0FiXXXFxVXa-30-30.png"/><img class="star" src="//laz-img-cdn.alicdn.com/tfs/TB14SXtAXOWBuNjy0FiXXXFxVXa-30-30.png"/></div>

# %%
#stars
star_rating=len(container.find_all())

# %%
#info
name = data.find_all('span', {'class':'pdp-mod-product-badge-title'})
price=  data.find_all('span', {'class':'pdp-price pdp-price_type_normal pdp-price_color_orange pdp-price_size_xl'})
ratings_ans_questions=data.find_all('a', {'class':'pdp-link pdp-link_size_s pdp-link_theme_blue pdp-review-summary__link'})
brand=data.find_all('a', {'class':"pdp-link pdp-link_size_s pdp-link_theme_blue pdp-product-brand__brand-link"})
location=data.find_all('div', {'class':"pdp-link pdp-link_size_s pdp-link_theme_blue pdp-product-brand__brand-link"})
star_rating=len(container.find_all())
address = delivery.find_all('div', {'class':'location__address'})
delivery_time =[delivery.find('div', {'class':'delivery-option-item__time'})]

# %%
#delivery
address = delivery.find_all('div', {'class':'location__address'})
delivery_time =[delivery.find('div', {'class':'delivery-option-item__time'})]
address
# Out:
# [<div class="location__address">Sindh, Karachi - Gulshan-e-Iqbal, Block 15</div>]

# %%
#positive_ratings
positive_ratings = responses.find_all('div', {'class':'seller-info-value rating-positive'})
ship_on_time =responses.find_all('div', {'class':'seller-info-value'})
chat_response_rating_ship_on_time=responses.find_all('div', {'class':'seller-info-value'})
#seperate work
stars = pagesrc.find('div', {'class':'container-star pdp-review-summary__stars pdp-stars_size_s'})
stars
# Out:
# <div class="container-star pdp-review-summary__stars pdp-stars_size_s"><img class="star" src="//laz-img-cdn.alicdn.com/tfs/TB14SXtAXOWBuNjy0FiXXXFxVXa-30-30.png"/><img class="star" src="//laz-img-cdn.alicdn.com/tfs/TB14SXtAXOWBuNjy0FiXXXFxVXa-30-30.png"/><img class="star" src="//laz-img-cdn.alicdn.com/tfs/TB14SXtAXOWBuNjy0FiXXXFxVXa-30-30.png"/><img class="star" src="//laz-img-cdn.alicdn.com/tfs/TB14SXtAXOWBuNjy0FiXXXFxVXa-30-30.png"/><img class="star" src="//laz-img-cdn.alicdn.com/tfs/TB14SXtAXOWBuNjy0FiXXXFxVXa-30-30.png"/></div>

# %%
#content=pagesrc.find('div', {'class':'content'})
reviews=content.find_all("span",{"class":"percent"})
reviews
# Out:
# [<span class="percent">86</span>,
#  <span class="percent">2</span>,
#  <span class="percent">0</span>,
#  <span class="percent">0</span>,
#  <span class="percent">0</span>]

# %%
import requests
from bs4 import BeautifulSoup as soup
from time import sleep

# %%
for i in ratings_ans_questions:
    v.append(i.text)
# Out:
# ['PYREX® 2-Cup / 500ml Glass Measuring Cup',
#  '88 Ratings',
#  '31 Answered Questions']

# %%
name = data.find_all('span', {'class':'pdp-mod-product-badge-title'})
price=  data.find_all('span', {'class':'pdp-price pdp-price_type_normal pdp-price_color_orange pdp-price_size_xl'})
ratings_ans_questions=data.find_all('a', {'class':'pdp-link pdp-link_size_s pdp-link_theme_blue pdp-review-summary__link'})
brand=data.find_all('a', {'class':"pdp-link pdp-link_size_s pdp-link_theme_blue pdp-product-brand__brand-link"})

delivery_time =[delivery.find('div', {'class':'delivery-option-item__time'})]

chat_response_rating_ship_on_time=responses.find_all('div', {'class':'seller-info-value'})
price
# Out:
# [<span class="pdp-price pdp-price_type_normal pdp-price_color_orange pdp-price_size_xl">Rs. 1,390</span>]

# %%
result=[["Name","Price","Total Ratings","Answered Questions","Delivery Time","Positive Ratings","Ship on Time","Chat Response Rate","Star Rating","5 star","4 star","4 star","3 star","2 star","1 star"]]
len(result[0])
# Out:
# 15

# %%
reviews=content.find_all("span",{"class":"percent"})
k=[]
for i in reviews:
    k.append(i.text)

# %%
k
# Out:
# ['86', '2', '0', '0', '0']

# %%
category=pagesrc.find_all("div",{"class":"breadcrumb_list breadcrumb_custom_cls"})
for i in category:
    print(i.text)
# Out:
# Kitchen & Dining
#
#
#
#
#
#
#
# Drinkware
#
#
#
#
#
#
#
# Cups, Mugs & Saucers
#
#
#
#
#
#
# PYREX® 2-Cup / 500ml Glass Measuring Cup

# %%
category=pagesrc.find_all("div",{"class":"breadcrumb_list breadcrumb_custom_cls"})
cat=[]
for i in category:
    cat.append(i.find_all("a"))
b=[]
for i in range(2):
    else:
        b.append(cat[0][i].text)
do=(b[0]+","+b[1])
str(do)
categ=do.replace("\n","")

# %%
#no of stars check////////////

# %%
for i in cat:
    print(i[0].text)
# Out:
# Kitchen & Dining

# %%
b=[]
for i in range(2):
    else:
        b.append(cat[0][i].text)
do=(b[0]+","+b[1])
str(do)
categ=do.replace("\n","")

# %%
do=(b[0]+","+b[1])
str(do)
categ=do.replace("\n","")

# %%
a=[name,price,categ,ratings_ans_questions,brand,delivery_time,chat_response_rating_ship_on_time,price,star_rating,reviews,address]

# %%
final=[]
for i in a:
    if i== star_rating:
        final.append(i)
    elif i== categ:
        final.append(i)
    else:
        for j in i:
            final.append(j.text)

# %%
final[2]
# Out:
# 'Kitchen & Dining,Drinkware'

# %%
final
# Out:
# ['PYREX® 2-Cup / 500ml Glass Measuring Cup',
#  'Rs. 1,390',
#  'Kitchen & Dining,Drinkware',
#  '88 Ratings',
#  '31 Answered Questions',
#  'Pyrex',
#  '4 - 6 days',
#  '95%',
#  '88%',
#  '100%',
#  'Rs. 1,390',
#  5,
#  '86',
#  '2',
#  '0',
#  '0',
#  '0',
#  'Sindh, Karachi - Gulshan-e-Iqbal, Block 15']

# %%
result=[["Name","Price","Category","Total Ratings","Answered Questions","Brand","Delivery Time","Positive Ratings","Ship on Time","Chat Response Rate","Star Rating","5 star","4 star","4 star","3 star","2 star","1 star","Delivery Address"]]
len(result[0])
# Out:
# 18

# %%
# my_url =  "//www.daraz.pk/products/printing-mug-with-pic-i133526253-s1293958049.html?search=1"


# driver = webdriver.Chrome(executable_path='C:\\Users\\Elitebook 850 G3\\anaconda\\New folder\\Lib\\site-packages\\jedi\\third_party\\typeshed\\stdlib\\3\\os\\chromedriver.exe')


# #driver = webdriver.Chrome()
# driver.get(my_url)
# print(driver)
# sleep(4)

# page = driver.page_source
# driver.close()

# pagesrc = soup(page, 'html.parser')

# #making a container to save all the data in
# container = pagesrc.find('div', {'class':'container-star pdp-review-summary__stars pdp-stars_size_s'})
# data= pagesrc.find('div', {'class':'pdp-block pdp-block__product-detail'})
# delivery= pagesrc.find('div', {'class':'delivery'})

# responses=pagesrc.find('div', {'class':'seller-container'})
# content=pagesrc.find('div', {'class':'content'})

# #our gallery is the product-item
# gallery = container.find_all('div', {'class':'pdp-mod-product-badge-wrapper'})

# sleep(1)
# #container-star pdp-review-summary__stars pdp-stars_size_s
# container

# %%
#info
name = data.find_all('span', {'class':'pdp-mod-product-badge-title'})
price=  data.find_all('span', {'class':'pdp-price pdp-price_type_normal pdp-price_color_orange pdp-price_size_xl'})
ratings_ans_questions=data.find_all('a', {'class':'pdp-link pdp-link_size_s pdp-link_theme_blue pdp-review-summary__link'})
brand=data.find_all('a', {'class':"pdp-link pdp-link_size_s pdp-link_theme_blue pdp-product-brand__brand-link"})
location=data.find_all('div', {'class':"pdp-link pdp-link_size_s pdp-link_theme_blue pdp-product-brand__brand-link"})
star_rating=len(container.find_all())
address = delivery.find_all('div', {'class':'location__address'})
delivery_time =[delivery.find('div', {'class':'delivery-option-item__time'})]
#positive_ratings
positive_ratings = responses.find_all('div', {'class':'seller-info-value rating-positive'})
ship_on_time =responses.find_all('div', {'class':'seller-info-value'})
chat_response_rating_ship_on_time=responses.find_all('div', {'class':'seller-info-value'})
#seperate work
stars = pagesrc.find('div', {'class':'container-star pdp-review-summary__stars pdp-stars_size_s'})
#content=pagesrc.find('div', {'class':'content'})
reviews=content.find_all("span",{"class":"percent"})
import requests
from bs4 import BeautifulSoup as soup
from time import sleep
name = data.find_all('span', {'class':'pdp-mod-product-badge-title'})
price=  data.find_all('span', {'class':'pdp-price pdp-price_type_normal pdp-price_color_orange pdp-price_size_xl'})
ratings_ans_questions=data.find_all('a', {'class':'pdp-link pdp-link_size_s pdp-link_theme_blue pdp-review-summary__link'})
brand=data.find_all('a', {'class':"pdp-link pdp-link_size_s pdp-link_theme_blue pdp-product-brand__brand-link"})

delivery_time =[delivery.find('div', {'class':'delivery-option-item__time'})]

chat_response_rating_ship_on_time=responses.find_all('div', {'class':'seller-info-value'})
category=pagesrc.find_all("div",{"class":"breadcrumb_list breadcrumb_custom_cls"})
cat=[]
for i in category:
    cat.append(i.find_all("a"))
b=[]
for i in range(2):
    else:
        b.append(cat[0][i].text)
do=(b[0]+","+b[1])
str(do)
categ=do.replace("\n","")
a=[name,price,categ,ratings_ans_questions,brand,delivery_time,chat_response_rating_ship_on_time,price,star_rating,reviews,address]
final=[]
for i in a:
    if i== star_rating:
        final.append(i)
    elif i== categ:
        final.append(i)
    else:
        for j in i:
            final.append(j.text)
final

# %%
import os
import sys
os.path.dirname(sys.executable)

result=[]
def func(f):
    from selenium import webdriver
    from selenium.webdriver.common.keys import Keys
    driver = webdriver.Chrome(executable_path='C:\\Users\\Elitebook 850 G3\\anaconda\\New folder\\Lib\\site-packages\\jedi\\third_party\\typeshed\\stdlib\\3\\os\\chromedriver.exe')
    import requests
    from bs4 import BeautifulSoup as soup
    from time import sleep
    from selenium import webdriver  
    driver.get("https://www.daraz.pk/")
    assert "Daraz" in driver.title
    find=driver.find_element_by_name("q")
    print(find.is_displayed())
    print(find.is_enabled())
    find.clear()
    find.send_keys(f)
    find.send_keys(Keys.RETURN)
    assert"no resultsfound" not in driver.page_source
    

    print(driver.current_url)
    
    my_url = driver.current_url
   

    #driver = webdriver.Chrome()
    driver.get(my_url)
    

    page = driver.page_source
    driver.close()
    pagesrc = soup(page, 'html.parser')

    #making a container to save all the data in
    container = pagesrc.find('div', {'class':'c1_t2i'})

    #our gallery is the product-item
    gallery = container.find_all('div', {'class':'c2prKC'})

    sleep(1)
    gallery =container.find_all('div', {'class':'cRjKsc'})
    anchor=[]
    for i in gallery:
        anchor.append(i.find("a"))
    links=[]
    for i in anchor:
        links.append("https:"+i.get("href"))
    print(links[21])
    print(links[23])
    
    for i in links:
        my_url =i
        driver = webdriver.Chrome(executable_path='C:\\Users\\Elitebook 850 G3\\anaconda\\New folder\\Lib\\site-packages\\jedi\\third_party\\typeshed\\stdlib\\3\\os\\chromedriver.exe')
        driver.get(my_url)
        print(driver)
        sleep(4)

        page = driver.page_source
        driver.close()

        pagesrc = soup(page, 'html.parser')

        #making a container to save all the data in
        container = pagesrc.find('div', {'class':'container-star pdp-review-summary__stars pdp-stars_size_s'})
        data= pagesrc.find('div', {'class':'pdp-block pdp-block__product-detail'})
        delivery= pagesrc.find('div', {'class':'delivery'})

        responses=pagesrc.find('div', {'class':'seller-container'})
        content=pagesrc.find('div', {'class':'content'})

        #our gallery is the product-item
        gallery = container.find_all('div', {'class':'pdp-mod-product-badge-wrapper'})

        sleep(1)
        #container-star pdp-review-summary__stars pdp-stars_size_s
        container
        #info
        name = data.find_all('span', {'class':'pdp-mod-product-badge-title'})
        price=  data.find_all('span', {'class':'pdp-price pdp-price_type_normal pdp-price_color_orange pdp-price_size_xl'})
        ratings_ans_questions=data.find_all('a', {'class':'pdp-link pdp-link_size_s pdp-link_theme_blue pdp-review-summary__link'})
        brand=data.find_all('a', {'class':"pdp-link pdp-link_size_s pdp-link_theme_blue pdp-product-brand__brand-link"})
        location=data.find_all('div', {'class':"pdp-link pdp-link_size_s pdp-link_theme_blue pdp-product-brand__brand-link"})
        star_rating=len(container.find_all())
        address = delivery.find_all('div', {'class':'location__address'})
        delivery_time =[delivery.find('div', {'class':'delivery-option-item__time'})]
        #positive_ratings
        positive_ratings = responses.find_all('div', {'class':'seller-info-value rating-positive'})
        ship_on_time =responses.find_all('div', {'class':'seller-info-value'})
        chat_response_rating_ship_on_time=responses.find_all('div', {'class':'seller-info-value'})
        #seperate work
        stars = pagesrc.find('div', {'class':'container-star pdp-review-summary__stars pdp-stars_size_s'})
        #content=pagesrc.find('div', {'class':'content'})
        reviews=content.find_all("span",{"class":"percent"})
        import requests
        from bs4 import BeautifulSoup as soup
        from time import sleep
        name = data.find_all('span', {'class':'pdp-mod-product-badge-title'})
        price=  data.find_all('span', {'class':'pdp-price pdp-price_type_normal pdp-price_color_orange pdp-price_size_xl'})
        ratings_ans_questions=data.find_all('a', {'class':'pdp-link pdp-link_size_s pdp-link_theme_blue pdp-review-summary__link'})
        brand=data.find_all('a', {'class':"pdp-link pdp-link_size_s pdp-link_theme_blue pdp-product-brand__brand-link"})

        delivery_time =[delivery.find('div', {'class':'delivery-option-item__time'})]

        chat_response_rating_ship_on_time=responses.find_all('div', {'class':'seller-info-value'})
        category=pagesrc.find_all("div",{"class":"breadcrumb_list breadcrumb_custom_cls"})
        cat=[]
        for i in category:
            cat.append(i.find_all("a"))
        b=[]
        for i in range(2):
            b.append(cat[0][i].text)
        do=(b[0]+","+b[1])
        str(do)
        categ=do.replace("\n","")
        a=[name,price,categ,ratings_ans_questions,brand,delivery_time,chat_response_rating_ship_on_time,price,star_rating,reviews,address]
        final=[]
        for i in a:
            if i== star_rating:
                final.append(i)
            elif i== categ:
                final.append(i)
            else:
                for j in i:
                    final.append(j.text)
        result.append(final)

# %%
func("watches")

# %%
links[22]
# Out:
# 'https://www.daraz.pk/products/reusable-straws-for-kids-fruit-cartoon-shape-spiral-drinking-straw-assorted-pack-of-4-i147810771-s1311228081.html?search=1'

# %%
result
# Out:
# [["Bostanten Men's Watch On Sale Waterproof business Watches For Men Original free Box",
#   'Rs. 1,849',
#   'Watches Sunglasses Jewellery,Watches',
#   '118 Ratings',
#   '31 Answered Questions',
#   'BOSTANTEN',
#   '26 - 33 days',
#   '93%',
#   '100%',
#   '99%',
#   'Rs. 1,849',
#   5,
#   '111',
#   '4',
#   '0',
#   '0',
#   '3',
#   'Sindh, Karachi - Gulshan-e-Iqbal, Block 15'],
#  ['BOSTANTEN Black quartz movement watch for men',
#   'Rs. 1,375',
#   'Watches Sunglasses Jewellery,Watches',
#   '618 Ratings',
#   '82 Answered Questions',
#   'BOSTANTEN',
#   '26 - 33 days',
#   '93%',
#   '100%',
#   '99%',
#   'Rs. 1,375',
#   5,
#   '573',
#   '24',
#   '8',
#   '2',
#   '11',
#   'Sindh, Karachi - Gulshan-e-Iqbal, Block 15'],
#  ['M3 Touch Led Bracelet Digital Watch Band',
#   'Rs. 299',
#   'Watches Sunglasses Jewellery,Watches',
#   '16 Ratings',
#   '1 Answered Questions',
#   'No Brand',
#   '4 - 6 days',
#   '100%',
#   '78%',
#   '100%',
#   'Rs. 299',
#   5,
# ...

# %%
import pandas as pd
df=pd.DataFrame(result)
df
# Out:
#                                                     0          1  \
# 0   Bostanten Men's Watch On Sale Waterproof busin...  Rs. 1,849
# 1       BOSTANTEN Black quartz movement watch for men  Rs. 1,375
# 2            M3 Touch Led Bracelet Digital Watch Band    Rs. 299
# 3   Waterproof Sport M4 Touch Led Digital Watch Fo...    Rs. 195
# 4   Pack of 2 Watches | Waterproof Digital Led Wat...    Rs. 398
# 5   Pack of 2 M3 Touch LED Sports Bracelet Digital...    Rs. 221
# 6   Best Quality Square Digital Silicone Sports Wa...    Rs. 228
# 7   Children Watches Kids LED Digital Sport Watch ...    Rs. 109
# 8   Pack of 2 M3 Touch Led Bracelet Digital Watch ...    Rs. 199
# 9        Waterproof Digital sports watch for Men Boys    Rs. 419
# 10                   Military Sports watch boys & men    Rs. 399
# 11  NEW LED digital Kids Watches for Girls/Boys Sp...    Rs. 105
# 12  OLAIVS Classic Luxury Watches for Men Watch Si...    Rs. 379
# ...

# %%
df.columns=["Name","Price","Category","Total Ratings","Answered Questions","Brand","Delivery Time","Positive Ratings","Ship on Time","Chat Response Rate","Star Rating","5 star","4 star","4 star","3 star","2 star","1 star","Delivery Address"]

# %%
df
# Out:
#                                                  Name      Price  \
# 0   Bostanten Men's Watch On Sale Waterproof busin...  Rs. 1,849
# 1       BOSTANTEN Black quartz movement watch for men  Rs. 1,375
# 2            M3 Touch Led Bracelet Digital Watch Band    Rs. 299
# 3   Waterproof Sport M4 Touch Led Digital Watch Fo...    Rs. 195
# 4   Pack of 2 Watches | Waterproof Digital Led Wat...    Rs. 398
# 5   Pack of 2 M3 Touch LED Sports Bracelet Digital...    Rs. 221
# 6   Best Quality Square Digital Silicone Sports Wa...    Rs. 228
# 7   Children Watches Kids LED Digital Sport Watch ...    Rs. 109
# 8   Pack of 2 M3 Touch Led Bracelet Digital Watch ...    Rs. 199
# 9        Waterproof Digital sports watch for Men Boys    Rs. 419
# 10                   Military Sports watch boys & men    Rs. 399
# 11  NEW LED digital Kids Watches for Girls/Boys Sp...    Rs. 105
# 12  OLAIVS Classic Luxury Watches for Men Watch Si...    Rs. 379
# ...

# %%
df.drop(0,axis=0)
# Out:
#                                                  Name      Price  \
# 1   Kotion Each G2000 Gaming Headset Surround Soun...  Rs. 2,599
# 2   ONIKUMA Gaming Headset K19 with RGB Glaring LE...  Rs. 2,599
# 3   Wireless Headphones, P47 Bluetooth Foldable He...    Rs. 699
# 4   KHM Z2 DAZZLING YELLOW Edition Handsfree Stere...    Rs. 237
# 5   P47 Wireless Bluetooth Headphones Latest 4.2+E...    Rs. 680
# 6   Wireless Headphones, P47 Bluetooth Foldable He...    Rs. 699
# 7   Woofer Headphones With Earhook Good Quality So...    Rs. 187
# 8   P47 Wireless Bluetooth Headphones Latest 4.2+E...    Rs. 699
# 9   Wireless Headphones, P47 Bluetooth Foldable He...    Rs. 699
# 10  P47 Wireless Bluetooth Foldable Headset With M...    Rs. 698
# 11  KOTION EACH G2000 Gaming Headset With Mic For ...  Rs. 2,725
# 12  AR 733 Stereo Base Boosted 3D audio Handsfree ...    Rs. 290
# 13  Bostanten Men's Watch On Sale Waterproof busin...  Rs. 1,849
# ...

# %%
df=df.drop(0,axis=0)

df=df.reset_index()

# %%
df
# Out:
#     index                                               Name      Price  \
# 0       1  Kotion Each G2000 Gaming Headset Surround Soun...  Rs. 2,599
# 1       2  ONIKUMA Gaming Headset K19 with RGB Glaring LE...  Rs. 2,599
# 2       3  Wireless Headphones, P47 Bluetooth Foldable He...    Rs. 699
# 3       4  KHM Z2 DAZZLING YELLOW Edition Handsfree Stere...    Rs. 237
# 4       5  P47 Wireless Bluetooth Headphones Latest 4.2+E...    Rs. 680
# 5       6  Wireless Headphones, P47 Bluetooth Foldable He...    Rs. 699
# 6       7  Woofer Headphones With Earhook Good Quality So...    Rs. 187
# 7       8  P47 Wireless Bluetooth Headphones Latest 4.2+E...    Rs. 699
# 8       9  Wireless Headphones, P47 Bluetooth Foldable He...    Rs. 699
# 9      10  P47 Wireless Bluetooth Foldable Headset With M...    Rs. 698
# 10     11  KOTION EACH G2000 Gaming Headset With Mic For ...  Rs. 2,725
# 11     12  AR 733 Stereo Base Boosted 3D audio Handsfree ...    Rs. 290
# ...

# %%
'https://www.daraz.pk/products/reusable-straws-for-kids-fruit-cartoon-shape-spiral-drinking-straw-assorted-pack-of-4-i147810771-s1311228081.html?search=1'

# %%
my_url =  "https://www.daraz.pk/products/stainless-steel-quartz-wirstwatch-for-men-with-box-i120480046-s1458904477.html?search=1"
driver = webdriver.Chrome(executable_path='C:\\Users\\Elitebook 850 G3\\anaconda\\New folder\\Lib\\site-packages\\jedi\\third_party\\typeshed\\stdlib\\3\\os\\chromedriver.exe')


#driver = webdriver.Chrome()
driver.get(my_url)
print(driver)
sleep(4)

page = driver.page_source
driver.close()

pagesrc = soup(page, 'html.parser')

#making a container to save all the data in
container = pagesrc.find('div', {'class':'container-star pdp-review-summary__stars pdp-stars_size_s'})
data= pagesrc.find('div', {'class':'pdp-block pdp-block__product-detail'})
delivery= pagesrc.find('div', {'class':'delivery'})

responses=pagesrc.find('div', {'class':'seller-container'})
content=pagesrc.find('div', {'class':'content'})

#our gallery is the product-item
gallery = container.find_all('div', {'class':'pdp-mod-product-badge-wrapper'})

sleep(1)
#container-star pdp-review-summary__stars pdp-stars_size_s
container
#info
name = data.find_all('span', {'class':'pdp-mod-product-badge-title'})
price=  data.find_all('span', {'class':'pdp-price pdp-price_type_normal pdp-price_color_orange pdp-price_size_xl'})
ratings_ans_questions=data.find_all('a', {'class':'pdp-link pdp-link_size_s pdp-link_theme_blue pdp-review-summary__link'})
brand=data.find_all('a', {'class':"pdp-link pdp-link_size_s pdp-link_theme_blue pdp-product-brand__brand-link"})
location=data.find_all('div', {'class':"pdp-link pdp-link_size_s pdp-link_theme_blue pdp-product-brand__brand-link"})
star_rating=len(container.find_all())
address = delivery.find_all('div', {'class':'location__address'})
delivery_time =[delivery.find('div', {'class':'delivery-option-item__time'})]
#positive_ratings
positive_ratings = responses.find_all('div', {'class':'seller-info-value rating-positive'})
ship_on_time =responses.find_all('div', {'class':'seller-info-value'})
chat_response_rating_ship_on_time=responses.find_all('div', {'class':'seller-info-value'})
#seperate work
stars = pagesrc.find('div', {'class':'container-star pdp-review-summary__stars pdp-stars_size_s'})
#content=pagesrc.find('div', {'class':'content'})
reviews=content.find_all("span",{"class":"percent"})
import requests
from bs4 import BeautifulSoup as soup
from time import sleep
name = data.find_all('span', {'class':'pdp-mod-product-badge-title'})
price=  data.find_all('span', {'class':'pdp-price pdp-price_type_normal pdp-price_color_orange pdp-price_size_xl'})
ratings_ans_questions=data.find_all('a', {'class':'pdp-link pdp-link_size_s pdp-link_theme_blue pdp-review-summary__link'})
brand=data.find_all('a', {'class':"pdp-link pdp-link_size_s pdp-link_theme_blue pdp-product-brand__brand-link"})

delivery_time =[delivery.find('div', {'class':'delivery-option-item__time'})]

chat_response_rating_ship_on_time=responses.find_all('div', {'class':'seller-info-value'})
category=pagesrc.find_all("div",{"class":"breadcrumb_list breadcrumb_custom_cls"})
cat=[]
for i in category:
    cat.append(i.find_all("a"))
b=[]
for i in range(2):
    b.append(cat[0][i].text)
do=(b[0]+","+b[1])
str(do)
categ=do.replace("\n","")
a=[name,price,categ,ratings_ans_questions,brand,delivery_time,chat_response_rating_ship_on_time,price,star_rating,reviews,address]
final=[]
for i in a:
    if i =="Null":
        final.append("NAN")
    elif i== star_rating:
        final.append(i)
    elif i== categ:
        final.append(i)
    else:
        for j in i:
            final.append(j.text)
final

# %%
import os
import sys
os.path.dirname(sys.executable)

result=[]
def func(f):
    from selenium import webdriver
    from selenium.webdriver.common.keys import Keys
    driver = webdriver.Chrome(executable_path='C:\\Users\\Elitebook 850 G3\\anaconda\\New folder\\Lib\\site-packages\\jedi\\third_party\\typeshed\\stdlib\\3\\os\\chromedriver.exe')
    import requests
    from bs4 import BeautifulSoup as soup
    from time import sleep
    from selenium import webdriver  
    driver.get("https://www.daraz.pk/")
    assert "Daraz" in driver.title
    find=driver.find_element_by_name("q")
    print(find.is_displayed())
    print(find.is_enabled())
    find.clear()
    find.send_keys(f)
    find.send_keys(Keys.RETURN)
    assert"no resultsfound" not in driver.page_source
    

    print(driver.current_url)
    
    my_url = driver.current_url
   

    #driver = webdriver.Chrome()
    driver.get(my_url)
    

    page = driver.page_source
    driver.close()
    pagesrc = soup(page, 'html.parser')

    #making a container to save all the data in
    container = pagesrc.find('div', {'class':'c1_t2i'})

    #our gallery is the product-item
    gallery = container.find_all('div', {'class':'c2prKC'})

    sleep(1)
    gallery =container.find_all('div', {'class':'cRjKsc'})
    anchor=[]
    for i in gallery:
        anchor.append(i.find("a"))
    links=[]
    for i in anchor:
        links.append("https:"+i.get("href"))
    print(links[21])
    print(links[23])
    
    for i in links:
        my_url =i
        driver = webdriver.Chrome(executable_path='C:\\Users\\Elitebook 850 G3\\anaconda\\New folder\\Lib\\site-packages\\jedi\\third_party\\typeshed\\stdlib\\3\\os\\chromedriver.exe')
        driver.get(my_url)
        print(driver)
        sleep(4)

        page = driver.page_source
        driver.close()

        pagesrc = soup(page, 'html.parser')

        #making a container to save all the data in
        container = pagesrc.find('div', {'class':'container-star pdp-review-summary__stars pdp-stars_size_s'})
        data= pagesrc.find('div', {'class':'pdp-block pdp-block__product-detail'})
        delivery= pagesrc.find('div', {'class':'delivery'})

        responses=pagesrc.find('div', {'class':'seller-container'})
        content=pagesrc.find('div', {'class':'content'})

        #our gallery is the product-item
        gallery = container.find_all('div', {'class':'pdp-mod-product-badge-wrapper'})

        sleep(1)
        #container-star pdp-review-summary__stars pdp-stars_size_s
        container
        #info
        name = data.find_all('span', {'class':'pdp-mod-product-badge-title'})
        price=  data.find_all('span', {'class':'pdp-price pdp-price_type_normal pdp-price_color_orange pdp-price_size_xl'})
        ratings_ans_questions=data.find_all('a', {'class':'pdp-link pdp-link_size_s pdp-link_theme_blue pdp-review-summary__link'})
        brand=data.find_all('a', {'class':"pdp-link pdp-link_size_s pdp-link_theme_blue pdp-product-brand__brand-link"})
        location=data.find_all('div', {'class':"pdp-link pdp-link_size_s pdp-link_theme_blue pdp-product-brand__brand-link"})
        star_rating=len(container.find_all())
        address = delivery.find_all('div', {'class':'location__address'})
        delivery_time =[delivery.find('div', {'class':'delivery-option-item__time'})]
        #positive_ratings
        positive_ratings = responses.find_all('div', {'class':'seller-info-value rating-positive'})
        ship_on_time =responses.find_all('div', {'class':'seller-info-value'})
        chat_response_rating_ship_on_time=responses.find_all('div', {'class':'seller-info-value'})
        #seperate work
        stars = pagesrc.find('div', {'class':'container-star pdp-review-summary__stars pdp-stars_size_s'})
        #content=pagesrc.find('div', {'class':'content'})
        reviews=content.find_all("span",{"class":"percent"})
        import requests
        from bs4 import BeautifulSoup as soup
        from time import sleep
        name = data.find_all('span', {'class':'pdp-mod-product-badge-title'})
        price=  data.find_all('span', {'class':'pdp-price pdp-price_type_normal pdp-price_color_orange pdp-price_size_xl'})
        ratings_ans_questions=data.find_all('a', {'class':'pdp-link pdp-link_size_s pdp-link_theme_blue pdp-review-summary__link'})
        brand=data.find_all('a', {'class':"pdp-link pdp-link_size_s pdp-link_theme_blue pdp-product-brand__brand-link"})

        delivery_time =[delivery.find('div', {'class':'delivery-option-item__time'})]

        chat_response_rating_ship_on_time=responses.find_all('div', {'class':'seller-info-value'})
        category=pagesrc.find_all("div",{"class":"breadcrumb_list breadcrumb_custom_cls"})
        cat=[]
        for i in category:
            cat.append(i.find_all("a"))
        b=[]
        for i in range(2):
            b.append(cat[0][i].text)
        do=(b[0]+","+b[1])
        str(do)
        categ=do.replace("\n","")
        a=[name,price,categ,ratings_ans_questions,brand,delivery_time,chat_response_rating_ship_on_time,price,star_rating,reviews,address]
        final=[]
        for i in a:
            if i== star_rating:
                final.append(i)
            elif i== categ:
                final.append(i)
            else:
                for j in i:
                    final.append(j.text)
        result.append(final)
