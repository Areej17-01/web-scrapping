# %%
import os
import sys
os.path.dirname(sys.executable)
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
def func(f):
    browser = webdriver.Chrome(executable_path='C:\\Users\\Elitebook 850 G3\\anaconda\\New folder\\Lib\\site-packages\\jedi\\third_party\\typeshed\\stdlib\\3\\os\\chromedriver.exe')
    browser.get("https://www.daraz.pk/")
    assert "Daraz" in browser.title
    find=browser.find_element_by_name("q")
    find.clear()
    find.send_keys(f)
    find.send_keys(Keys.RETURN)
    assert"no resultsfound" not in browser.page_source
    print(browser.current_url)

# %%
headph=func("head phones")
# Out:
# https://www.daraz.pk/catalog/?q=head+phones&_keyori=ss&from=input&spm=a2a0e.home.search.go.35e34937fQm32z

# %%
import requests
from bs4 import BeautifulSoup

# %%
base_site="https://www.daraz.pk/catalog/?q=head+phones&_keyori=ss&from=input&spm=a2a0e.home.search.go.35e34937Vgge7l"
response=requests.get(base_site)
response
# Out:
# <Response [200]>

# %%
html=response.text

# %%
soup=BeautifulSoup(html,"html.parser")

# %%
body=soup.find("body")
body.find_all("a",title='<div class="c3gUW0">')
# Out:
# []

# %%
body
# Out:
# <body data-spm="searchlist"><script>
# with(document)with(body)with(insertBefore(createElement("script"),firstChild))setAttribute("exparams","cfgver=1.0&aplus&asid=AQAAAABgwtpgRlALJAAAAAB+6yS0AXV5Tg==",id="beacon-aplus",src="//assets.alicdn.com/g/alilog??aplus_plugin_lazada/daraz_loader.js,mlog/aplus_int.js")
# </script>
# <script>
#         window.LZD_RETCODE_SAMPLE=100;
#         if("daraz" === 'daraz') {
#             window.LZD_RETCODE_PAGENAME = "daraz-search-desktop";
#         } else {
#             window.LZD_RETCODE_PAGENAME = "lzd-search-desktop";
#         }
#     </script>
# <script>
#     window.__bl ={};
#     window._blReport=function(e,t){window.__bl&&(__bl.api?__bl[e].apply(__bl,t):(__bl.pipe=__bl.pipe||[],__bl.pipe.push([e].concat(t))))},window.addEventListener("error",function(e){_blReport("error",[e.error,e])}),window.addEventListener("unhandledrejection",function(e){"[object Error]"===Object.prototype.toString.call(e.reason)&&_blReport("error",[e.reason])});
# ...
